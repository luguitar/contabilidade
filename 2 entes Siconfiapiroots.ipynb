# %%
import json, requests
import pandas as pd

# %%
urlEntes = 'https://apidatalake.tesouro.gov.br/ords/siconfi/tt/entes'
urlDCA = 'https://apidatalake.tesouro.gov.br/ords/siconfi/tt/dca?an_exercicio={0}&id_ente={1}'
urlEntregas = 'https://apidatalake.tesouro.gov.br/ords/siconfi/tt/extrato_entregas?id_ente={0}&an_referencia={1}'
urlRREO = 'https://apidatalake.tesouro.gov.br/ords/siconfi/tt/rreo?an_exercicio={0}&nr_periodo={1}&co_tipo_demonstrativo={2}&no_anexo={3}&id_ente={4}'

# %%
'''jsonData = requests.get(urlEntes)
data = json.loads(jsonData.text)
entes = pd.DataFrame(data['items'])
entes'''
# Out:
# "jsonData = requests.get(urlEntes)\ndata = json.loads(jsonData.text)\nentes = pd.DataFrame(data['items'])\nentes"

# %%
an_exercicio = 2021
id_ente = 33
jsonData = requests.get(urlEntregas.format(id_ente, an_exercicio))
data = json.loads(jsonData.text)
entregas = pd.DataFrame(data['items'])
entregas
#dca['valor']
#dca['anexo'].unique()
#dca.to_excel('dca.xlsx')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# TimeoutError: [Errno 110] Connection timed out
#
# ...

# %%
an_exercicio = 2022
id_ente = 4310405
periodo = 1
#tipo_rreo = 'RREO%20Simplificado'
tipo_rreo = 'RREO'
#anexo = 'RREO-Anexo%2001'
anexo = 'RREO-Anexo%2002'
jsonData = requests.get(urlRREO.format(an_exercicio, periodo, tipo_rreo, anexo, id_ente))
data = json.loads(jsonData.text)
rreo = pd.DataFrame(data['items'])
rreo
rreo.to_excel('rreo_a01.xlsx')
